# %%
import pandas as pd

df = pd.read_csv('../data/raw/LENDHIST2019_2020_utf8.csv')

df.head(20)
# Out:
#                               USERID  BIRTHYEAR SEX         DEPT  \
# 0   b1e9675eeacb2d6edcf031bdac1bf0df     1990.0   女  应用金融与行为科学学院
# 1   860b7ac7a8a12790da3d77d53e265a21     1998.0   女       公共管理学院
# 2   5a9b0d6f361f4832a93db1ba02a73adc     1996.0   女         会计学院
# 3   ca2bc2cb7fc2c5e66075aa6b6387c123     1989.0   男         经济学院
# 4   dca2a9c89a64cbfb95506b69570b9cb6     1996.0   女          法学院
# 5   dca2a9c89a64cbfb95506b69570b9cb6     1996.0   女          法学院
# 6   c04bd4a8ff0f1eda5d94faa5d7af7b52     1986.0   男         经济学院
# 7   c04bd4a8ff0f1eda5d94faa5d7af7b52     1986.0   男         经济学院
# 8   24d6778d43a52172ee86499f5b3d591d     1998.0   男       萨里国际学院
# 9   b890453d3184742e583fe1a781a9982a     1998.0   女          法学院
# 10  c5f143b0dd524a707abee1c7453f4cf6     2001.0   男       萨里国际学院
# 11  85102325ca0b85d2735c484362c70b6a     1994.0   男          法学院
# 12  aa26beccee519112e8cce7c7dfcfef78     1988.0   男       财政税务学院
# ...
